# %% [markdown]
# <a href="https://colab.research.google.com/github/FerlynCallada/Ferlyn-L.-Callada/blob/main/Data_Preprocessing_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount,("/content/drive")

# %% [markdown]
#  1. Using the Colab notebook, import the following packages/ libraries/
#
# *   List item
# *   List item
#
# modules:

# %%
import os as os
import numpy as np
import pandas as pd
from matplotlib import pyplot as mpl
import seaborn as sb
import warnings as wn

# %%
path = "/content/drive/MyDrive/Colab Notebooks/LabExercise3/loans.csv"

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LabExercise3/loans.csv')

# %%
df.set_index('client_id', inplace = True)

# %%
df.head(5)
# Out:
#           loan_type  loan_amount  repaid  loan_id  loan_start    loan_end  \
# client_id
# 46109          home        13672       0    10243  2002-04-16  2003-12-20
# 46109        credit         9794       0    10984  2003-10-21  2005-07-17
# 46109          home        12734       1    10990  2006-02-01  2007-07-05
# 46109          cash        12518       1    10596  2010-12-08  2013-05-05
# 46109        credit        14049       1    11415  2010-07-07  2012-05-21
#
#            rate
# client_id
# 46109      2.15
# 46109      1.25
# 46109      0.68
# 46109      1.24
# 46109      3.13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 46109 to 26945
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   loan_type    443 non-null    object
#  1   loan_amount  443 non-null    int64
#  2   repaid       443 non-null    int64
#  3   loan_id      443 non-null    int64
#  4   loan_start   443 non-null    object
#  5   loan_end     443 non-null    object
#  6   rate         443 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 27.7+ KB

# %%
df.isnull().sum()
# Out:
# loan_type      0
# loan_amount    0
# repaid         0
# loan_id        0
# loan_start     0
# loan_end       0
# rate           0
# dtype: int64

# %%
numeric_columns = ['loan_amount','repaid','rate']
for col in numeric_columns:
  mpl.figure(figsize=(8,5))
sns.boxplot(x=df[col])
mpl.title(f'Boxplot for {col}')
mpl.show()

# %%
# Assume that df is the DataFrame
numeric_columns = ['loan_amount']


# Create new DataFrame with the SQAURE ROOT Transformation
df_sqrt_transformed = df.copy()
df_sqrt_transformed['loan_amount_sqrt'] = np.sqrt(df['loan_amount'])

# Create a side-by-side boxplots
mpl.figure(figsize=(12,6))

# Original data
mpl.subplot(1,2,1)
sb.boxplot(x=df['loan_amount'])
mpl.title('Original Loan Amount')

# Square root transformed data
mpl.subplot(1, 2, 2)
sb.boxplot(x=df_sqrt_transformed['loan_amount_sqrt'])
mpl.title('Loan Amount after SQR Transformation')

mpl.tight_layout()
mpl.show()

# %%
# Assume that df is the DataFrame
numeric_columns = ['repaid']


# Create new DataFrame with the SQAURE ROOT Transformation
df_sqrt_transformed = df.copy()
df_sqrt_transformed['repaid_sqrt'] = np.sqrt(df['repaid'])

# Create a side-by-side boxplots
mpl.figure(figsize=(12,6))

# Original data
mpl.subplot(1,2,1)
sb.boxplot(x=df['repaid'])
mpl.title('Original Repaid')

# Square root transformed data
mpl.subplot(1, 2, 2)
sb.boxplot(x=df_sqrt_transformed['repaid_sqrt'])
mpl.title('Repaid after SQR Transformation')

mpl.tight_layout()
mpl.show()

# %%
# Assume that df is the DataFrame
numeric_columns = ['rate']


# Create new DataFrame with the SQAURE ROOT Transformation
df_sqrt_transformed = df.copy()
df_sqrt_transformed['rate_sqrt'] = np.sqrt(df['rate'])

# Create a side-by-side boxplots
mpl.figure(figsize=(12,6))

# Original data
mpl.subplot(1,2,1)
sb.boxplot(x=df['rate'])
mpl.title('Original Rate')

# Square root transformed data
mpl.subplot(1, 2, 2)
sb.boxplot(x=df_sqrt_transformed['rate_sqrt'])
mpl.title('Rate after SQR Transformation')

mpl.tight_layout()
mpl.show()

# %%
from scipy.stats import zscore

# %%
# Assume that df is the DataFrame
numeric_columns = ['loan_amount']

# Calculate z-scores
z_score = zscore(df['loan_amount'])

# Create new DataFrame with the SQAURE ROOT Transformation
df_zscore_capped = df.copy()
df_zscore_capped['loan_amount_zscore_capped'] = np.where((z_scores > 3) | (z_scores < -3), np.median(df['loan_amount']), df['loan_amount'])

# Create a side-by-side boxplots
mpl.figure(figsize=(12,6))

# Original data
mpl.subplot(1,2,1)
sb.boxplot(x=df['loan_amount'])
mpl.title('Original Loan Amount')

# Z-score capped data
mpl.subplot(1, 2, 2)
sb.boxplot(x=df_zscore_capped['loan_amount_zscore_capped'])
mpl.title('Loan Amount after Z-score Capping')

mpl.tight_layout()
mpl.show()

# %%
# Assume that df is the DataFrame
numeric_columns = ['repaid']

# Calculate z-scores
z_score = zscore(df['repaid'])

# Create new DataFrame with the SQAURE ROOT Transformation
df_zscore_capped = df.copy()
df_zscore_capped['repaid_zscore_capped'] = np.where((z_scores > 3) | (z_scores < -3), np.median(df['repaid']), df['repaid'])

# Create a side-by-side boxplots
mpl.figure(figsize=(12,6))

# Original data
mpl.subplot(1,2,1)
sb.boxplot(x=df['repaid'])
mpl.title('Original Repaid')

# Z-score capped data
mpl.subplot(1, 2, 2)
sb.boxplot(x=df_zscore_capped['repaid_zscore_capped'])
mpl.title('Repaid after Z-score Capping')

mpl.tight_layout()
mpl.show()

# %%
# Assume that df is the DataFrame
numeric_columns = ['rate']

# Calculate z-scores
z_score = zscore(df['rate'])

# Create new DataFrame with the SQAURE ROOT Transformation
df_zscore_capped = df.copy()
df_zscore_capped['rate_zscore_capped'] = np.where((z_scores > 3) | (z_scores < -3), np.median(df['rate']), df['rate'])

# Create a side-by-side boxplots
mpl.figure(figsize=(12,6))

# Original data
mpl.subplot(1,2,1)
sb.boxplot(x=df['rate'])
mpl.title('Original Rate')

# Z-score capped data
mpl.subplot(1, 2, 2)
sb.boxplot(x=df_zscore_capped['rate_zscore_capped'])
mpl.title('Rate after Z-score Capping')

mpl.tight_layout()
mpl.show()

# %% [markdown]
# Apply scaling using Min-Max Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Assumes the df is the DataFrame
numeric_columns = ['loan_amount', 'repaid', 'rate']

# Create copy of DataFrame for Visualization
df_normalized = df.copy()

# Apply Min-Max Normalization
scaler = MinMaxScaler()
df_normalized[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Visualized the Distribution before and after normalization
mpl.figure(figsize=(12, 6))

# Before normalization
mpl.subplot(1,2,1)
for col in numeric_columns:
  sb.histplot(df_normalized[col], kde = True, label=col, alpha=0.5)
mpl.title('Before Min-Max Normalization')
mpl.legend()

# After normalization
mpl.subplot(1,2,2)
for col in numeric_columns:
    sb.histplot(df_normalized[col], kde = True, label=col, alpha=0.5)
mpl.title('After Min-Max Normalization')
mpl.legend()

mpl.tight_layout()
mpl.show()

# Assuming df_normalized is the DataFrame after normalization
sb.pairplot(df_normalized[numeric_columns])
mpl.show()

print("Before Min-Max Normalization:")
print(df[numeric_columns].describe())

print("\nAfter Min-Max Normalization:")
print(df_normalized[numeric_columns].describe())
# Out:
# Before Min-Max Normalization:
#         loan_amount      repaid        rate
# count    443.000000  443.000000  443.000000
# mean    7982.311512    0.534989    3.217156
# std     4172.891992    0.499338    2.397168
# min      559.000000    0.000000    0.010000
# 25%     4232.500000    0.000000    1.220000
# 50%     8320.000000    1.000000    2.780000
# 75%    11739.000000    1.000000    4.750000
# max    14971.000000    1.000000   12.620000
#
# After Min-Max Normalization:
#        loan_amount      repaid        rate
# count   443.000000  443.000000  443.000000
# mean      0.515079    0.534989    0.254334
# std       0.289543    0.499338    0.190101
# min       0.000000    0.000000    0.000000
# 25%       0.254892    0.000000    0.095956
# 50%       0.538510    1.000000    0.219667
# 75%       0.775742    1.000000    0.375892
# max       1.000000    1.000000    1.000000

# %% [markdown]
# Display the skewness and kurtosis graphs for Loan Amount and explain the results.

# %%
from scipy.stats import skew, kurtosis

# %%
# Assuming df is the DataFrame
loan_amount_skewness = skew(df['loan_amount'])
loan_amount_kurtosis = kurtosis(df['loan_amount'])

print(f"Skewness of Loan Amount: {loan_amount_skewness}")
print(f"Kurtosis of Loan Amount: {loan_amount_kurtosis}")

# You can also visualize the distribution
mpl.figure(figsize=(8, 6))
sb.histplot(df['loan_amount'], kde=True)
mpl.title('Distribution of Loan Amount after Min-Max Normalization')
mpl.show()
# Out:
# Skewness of Loan Amount: -0.03997926438774986
# Kurtosis of Loan Amount: -1.2317500314875274

# %% [markdown]
# As for the categorical features, apply encoding of categorical variables into dummy variables using pd.get_dummies approach. Show the first five (5) rows.

# %%
# Assuming df is the DataFrame
categorial_columns = ['loan_type']

# Apply pd.get_dummies
df_encoded = pd.get_dummies(df, columns=categorial_columns, drop_first=True)

#Display the first five rows
print(df_encoded.head())
# Out:
#    client_id  loan_amount  repaid  loan_id  loan_start    loan_end  rate  \
# 0      46109        13672       0    10243  2002-04-16  2003-12-20  2.15
# 1      46109         9794       0    10984  2003-10-21  2005-07-17  1.25
# 2      46109        12734       1    10990  2006-02-01  2007-07-05  0.68
# 3      46109        12518       1    10596  2010-12-08  2013-05-05  1.24
# 4      46109        14049       1    11415  2010-07-07  2012-05-21  3.13
#
#    loan_type_credit  loan_type_home  loan_type_other
# 0                 0               1                0
# 1                 1               0                0
# 2                 0               1                0
# 3                 0               0                0
# 4                 1               0                0

# %%
# Assuming df is the DataFrame
df['loan_start'] = pd.to_datetime(df['loan_start'])
df['loan_end'] = pd.to_datetime(df['loan_end'])

df['loan_tenure_days'] = (df['loan_end'] - df['loan_start']).dt.days

print(df[['loan_start', 'loan_end', 'loan_tenure_days']].head())
# Out:
#   loan_start   loan_end  loan_tenure_days
# 0 2002-04-16 2003-12-20               613
# 1 2003-10-21 2005-07-17               635
# 2 2006-02-01 2007-07-05               519
# 3 2010-12-08 2013-05-05               879
# 4 2010-07-07 2012-05-21               684

# %% [markdown]
#  Create new derived features to calculate the tenure of the loan by using the loan_start and loan_end.

# %%
from sklearn.model_selection import train_test_split

# Assuming df is the DataFrame
features = df.drop(['loan_amount','loan_id','loan_start', 'loan_end'], axis=1)
target = df['loan_amount']

# Check the shape of features and target
print("Features shape:", features.shape)
print("Target shape:", target.shape)

# Split the data into training  and testing sets (80-20 division)
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# Features shape: (443, 5)
# Target shape: (443,)
# x_train shape: (354, 5)
# x_test shape: (89, 5)
# y_train shape: (354,)
# y_test shape: (89,)
